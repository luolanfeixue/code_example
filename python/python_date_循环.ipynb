# %%
sql_str ="alter table  btcf_jd.dwd_jdmall_up_app_ba_userprofile_prop_nonpolar_view_ext_s_d drop partition(dt='{}')"

# %%
import datetime

# %%
begin = datetime.date(2018,10,8)
end = datetime.date(2019,2,24)
d = begin
delta = datetime.timedelta(days=1)
while d <= end:
    dt = d.strftime("%Y%m%d")
    sql_str ="alter table  btcf_jd.dwd_jdmall_up_app_ba_userprofile_prop_nonpolar_view_ext_s_d drop partition(dt='{0}');".format(dt)
    print(sql_str)
    d += delta
# Out:
# alter table  btcf_jd.dwd_jdmall_up_app_ba_userprofile_prop_nonpolar_view_ext_s_d drop partition(dt='20181008');
# alter table  btcf_jd.dwd_jdmall_up_app_ba_userprofile_prop_nonpolar_view_ext_s_d drop partition(dt='20181009');
# alter table  btcf_jd.dwd_jdmall_up_app_ba_userprofile_prop_nonpolar_view_ext_s_d drop partition(dt='20181010');
# alter table  btcf_jd.dwd_jdmall_up_app_ba_userprofile_prop_nonpolar_view_ext_s_d drop partition(dt='20181011');
# alter table  btcf_jd.dwd_jdmall_up_app_ba_userprofile_prop_nonpolar_view_ext_s_d drop partition(dt='20181012');
# alter table  btcf_jd.dwd_jdmall_up_app_ba_userprofile_prop_nonpolar_view_ext_s_d drop partition(dt='20181013');
# alter table  btcf_jd.dwd_jdmall_up_app_ba_userprofile_prop_nonpolar_view_ext_s_d drop partition(dt='20181014');
# alter table  btcf_jd.dwd_jdmall_up_app_ba_userprofile_prop_nonpolar_view_ext_s_d drop partition(dt='20181015');
# ...
